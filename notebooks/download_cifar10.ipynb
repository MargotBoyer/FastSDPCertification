# %%
import torchvision
import torchvision.transforms as transforms
from tools import get_project_path

# Dossier où sera téléchargé CIFAR-10
data_dir = get_project_path("./data/datasets")

# Transformations basiques (optionnel)
transform = transforms.Compose([
    transforms.ToTensor()
])

# Download des datasets
train_set = torchvision.datasets.CIFAR10(
    root=data_dir, train=True, download=True, transform=transform
)

test_set = torchvision.datasets.CIFAR10(
    root=data_dir, train=False, download=True, transform=transform
)

print("CIFAR-10 téléchargé !")
print("Train samples :", len(train_set))
print("Test samples :", len(test_set))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /share/homes/boyerma/FastSDPCertification/./data/datasets/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:07<00:00, 22180208.15it/s]
# Extracting /share/homes/boyerma/FastSDPCertification/./data/datasets/cifar-10-python.tar.gz to /share/homes/boyerma/FastSDPCertification/./data/datasets
# Files already downloaded and verified
# CIFAR-10 téléchargé !
# Train samples : 50000
# Test samples : 10000
